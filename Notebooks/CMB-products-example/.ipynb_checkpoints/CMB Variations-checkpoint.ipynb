# %% [markdown]
# # Plotting Variations in the Cosmic Microwave Background
#
# In order to further my understanding of how the CMB is constructed, I've done a series of runs with Camb (inside Cosmosis) varying one parameter from the Planck best fit cosmological parameters. I'm starting with the basic six parameters, but will ultimately include second order parameters (eg: lensing and neutrinos) to see how these affect the CMB as well.

# %%
# Start with the basics

import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Specify powerspectra file locations

# Nominal best fit cmb
file_nominal = '/Users/winn/Research/Thesis/CMB-products/nominal/nominal_11-9-17/cmb_cl/tt.txt'
file_axis = '/Users/winn/Research/Thesis/CMB-products/nominal/nominal_11-9-17/cmb_cl/ell.txt'

# Varying h_0...
file_h0_0_20 = '/Users/winn/Research/Thesis/CMB-products/h_0/h_0-0.20/cmb_cl/tt.txt'
file_h0_0_30 = '/Users/winn/Research/Thesis/CMB-products/h_0/h_0-0.30/cmb_cl/tt.txt'
file_h0_0_40 = '/Users/winn/Research/Thesis/CMB-products/h_0/h_0-0.40/cmb_cl/tt.txt'
file_h0_0_50 = '/Users/winn/Research/Thesis/CMB-products/h_0/h_0-0.50/cmb_cl/tt.txt'
file_h0_0_60 = '/Users/winn/Research/Thesis/CMB-products/h_0/h_0-0.60/cmb_cl/tt.txt'
file_h0_0_65 = '/Users/winn/Research/Thesis/CMB-products/h_0/h_0-0.65/cmb_cl/tt.txt'
file_h0_0_66 = '/Users/winn/Research/Thesis/CMB-products/h_0/h_0-0.66/cmb_cl/tt.txt'
file_h0_0_68 = '/Users/winn/Research/Thesis/CMB-products/h_0/h_0-0.68/cmb_cl/tt.txt'
file_h0_0_69 = '/Users/winn/Research/Thesis/CMB-products/h_0/h_0-0.69/cmb_cl/tt.txt'
file_h0_0_70 = '/Users/winn/Research/Thesis/CMB-products/h_0/h_0-0.70/cmb_cl/tt.txt'
file_h0_0_80 = '/Users/winn/Research/Thesis/CMB-products/h_0/h_0-0.80/cmb_cl/tt.txt'
file_h0_0_90 = '/Users/winn/Research/Thesis/CMB-products/h_0/h_0-0.90/cmb_cl/tt.txt'
file_h0_0_100 = '/Users/winn/Research/Thesis/CMB-products/h_0/h_0-1.00/cmb_cl/tt.txt'

# Varying tau...
file_tau_0_01 = '/Users/winn/Research/Thesis/CMB-products/tau/tau-0.01/cmb_cl/tt.txt'
file_tau_0_02 = '/Users/winn/Research/Thesis/CMB-products/tau/tau-0.02/cmb_cl/tt.txt'
file_tau_0_03 = '/Users/winn/Research/Thesis/CMB-products/tau/tau-0.03/cmb_cl/tt.txt'
file_tau_0_04 = '/Users/winn/Research/Thesis/CMB-products/tau/tau-0.04/cmb_cl/tt.txt'
file_tau_0_05 = '/Users/winn/Research/Thesis/CMB-products/tau/tau-0.05/cmb_cl/tt.txt'
file_tau_0_06 = '/Users/winn/Research/Thesis/CMB-products/tau/tau-0.06/cmb_cl/tt.txt'
file_tau_0_07 = '/Users/winn/Research/Thesis/CMB-products/tau/tau-0.07/cmb_cl/tt.txt'
file_tau_0_09 = '/Users/winn/Research/Thesis/CMB-products/tau/tau-0.09/cmb_cl/tt.txt'
file_tau_0_10 = '/Users/winn/Research/Thesis/CMB-products/tau/tau-0.10/cmb_cl/tt.txt'
file_tau_0_11 = '/Users/winn/Research/Thesis/CMB-products/tau/tau-0.11/cmb_cl/tt.txt'
file_tau_0_50 = '/Users/winn/Research/Thesis/CMB-products/tau/tau-0.50/cmb_cl/tt.txt'

# Varying n_s...
file_ns_0_20 = '/Users/winn/Research/Thesis/CMB-products/n_s/n_s-0.20/cmb_cl/tt.txt'
file_ns_0_50 = '/Users/winn/Research/Thesis/CMB-products/n_s/n_s-0.50/cmb_cl/tt.txt'
file_ns_0_70 = '/Users/winn/Research/Thesis/CMB-products/n_s/n_s-0.70/cmb_cl/tt.txt'
file_ns_0_80 = '/Users/winn/Research/Thesis/CMB-products/n_s/n_s-0.80/cmb_cl/tt.txt'
file_ns_0_90 = '/Users/winn/Research/Thesis/CMB-products/n_s/n_s-0.90/cmb_cl/tt.txt'
file_ns_1_00 = '/Users/winn/Research/Thesis/CMB-products/n_s/n_s-1.00/cmb_cl/tt.txt'
file_ns_1_10 = '/Users/winn/Research/Thesis/CMB-products/n_s/n_s-1.10/cmb_cl/tt.txt'
file_ns_1_20 = '/Users/winn/Research/Thesis/CMB-products/n_s/n_s-1.20/cmb_cl/tt.txt'

# Varying A_s...
file_A_s_0_50 = '/Users/winn/Research/Thesis/CMB-products/A_s/A_s-0-50/cmb_cl/tt.txt'
file_A_s_1_00 = '/Users/winn/Research/Thesis/CMB-products/A_s/A_s-1-00/cmb_cl/tt.txt'
file_A_s_1_50 = '/Users/winn/Research/Thesis/CMB-products/A_s/A_s-1-50/cmb_cl/tt.txt'
file_A_s_2_00 = '/Users/winn/Research/Thesis/CMB-products/A_s/A_s-2-00/cmb_cl/tt.txt'
file_A_s_2_50 = '/Users/winn/Research/Thesis/CMB-products/A_s/A_s-2-50/cmb_cl/tt.txt'
file_A_s_3_00 = '/Users/winn/Research/Thesis/CMB-products/A_s/A_s-3-00/cmb_cl/tt.txt'
file_A_s_3_50 = '/Users/winn/Research/Thesis/CMB-products/A_s/A_s-3-50/cmb_cl/tt.txt'

# Varying omega_lambda vs. omega_m (holding proportion of omega_c / omega_m constant)
file_omega_lambda_0_50 = '/Users/winn/Research/Thesis/CMB-products/omega_lambda/omega_lambda-0.50/cmb_cl/tt.txt'
file_omega_lambda_0_60 = '/Users/winn/Research/Thesis/CMB-products/omega_lambda/omega_lambda-0.60/cmb_cl/tt.txt'
file_omega_lambda_0_80 = '/Users/winn/Research/Thesis/CMB-products/omega_lambda/omega_lambda-0.80/cmb_cl/tt.txt'
file_omega_lambda_0_90 = '/Users/winn/Research/Thesis/CMB-products/omega_lambda/omega_lambda-0.90/cmb_cl/tt.txt'

# Varying omega_b vs. omega_c (holding omega_lambda constant at ~0.69)
file_omega_b_0_005 = '/Users/winn/Research/Thesis/CMB-products/omega_b-omega_c/omega_b-0.005/cmb_cl/tt.txt'
file_omega_b_0_010 = '/Users/winn/Research/Thesis/CMB-products/omega_b-omega_c/omega_b-0.010/cmb_cl/tt.txt'
file_omega_b_0_100 = '/Users/winn/Research/Thesis/CMB-products/omega_b-omega_c/omega_b-0.100/cmb_cl/tt.txt'
file_omega_b_0_313 = '/Users/winn/Research/Thesis/CMB-products/omega_b-omega_c/omega_b-0.313/cmb_cl/tt.txt'

# Ultimately I decided that varying neutrinos wouldn't be a worthwhile exercise.

# %%
# Load the data...

data_nominal = np.loadtxt(file_nominal,skiprows=1)
axis = np.loadtxt(file_axis,skiprows=1)

data_h0_0_20 = np.loadtxt(file_h0_0_20,skiprows=1)
data_h0_0_30 = np.loadtxt(file_h0_0_30,skiprows=1)
data_h0_0_40 = np.loadtxt(file_h0_0_40,skiprows=1)
data_h0_0_50 = np.loadtxt(file_h0_0_50,skiprows=1)
data_h0_0_60 = np.loadtxt(file_h0_0_60,skiprows=1)
data_h0_0_65 = np.loadtxt(file_h0_0_65,skiprows=1)
data_h0_0_66 = np.loadtxt(file_h0_0_66,skiprows=1)
data_h0_0_68 = np.loadtxt(file_h0_0_68,skiprows=1)
data_h0_0_69 = np.loadtxt(file_h0_0_69,skiprows=1)
data_h0_0_70 = np.loadtxt(file_h0_0_70,skiprows=1)
data_h0_0_80 = np.loadtxt(file_h0_0_80,skiprows=1)
data_h0_0_90 = np.loadtxt(file_h0_0_90,skiprows=1)
data_h0_0_100 = np.loadtxt(file_h0_0_100,skiprows=1)

data_tau_0_01 = np.loadtxt(file_tau_0_01,skiprows=1)
data_tau_0_02 = np.loadtxt(file_tau_0_02,skiprows=1)
data_tau_0_03 = np.loadtxt(file_tau_0_03,skiprows=1)
data_tau_0_04 = np.loadtxt(file_tau_0_04,skiprows=1)
data_tau_0_05 = np.loadtxt(file_tau_0_05,skiprows=1)
data_tau_0_06 = np.loadtxt(file_tau_0_06,skiprows=1)
data_tau_0_07 = np.loadtxt(file_tau_0_07,skiprows=1)
data_tau_0_09 = np.loadtxt(file_tau_0_09,skiprows=1)
data_tau_0_10 = np.loadtxt(file_tau_0_10,skiprows=1)
data_tau_0_11 = np.loadtxt(file_tau_0_11,skiprows=1)
data_tau_0_50 = np.loadtxt(file_tau_0_50,skiprows=1)

data_ns_0_20 = np.loadtxt(file_ns_0_20,skiprows=1)
data_ns_0_50 = np.loadtxt(file_ns_0_50,skiprows=1)
data_ns_0_70 = np.loadtxt(file_ns_0_70,skiprows=1)
data_ns_0_80 = np.loadtxt(file_ns_0_80,skiprows=1)
data_ns_0_90 = np.loadtxt(file_ns_0_90,skiprows=1)
data_ns_1_00 = np.loadtxt(file_ns_1_00,skiprows=1)
data_ns_1_10 = np.loadtxt(file_ns_1_10,skiprows=1)
data_ns_1_20 = np.loadtxt(file_ns_1_20,skiprows=1)

data_A_s_0_50 = np.loadtxt(file_A_s_0_50,skiprows=1)
data_A_s_1_00 = np.loadtxt(file_A_s_1_00,skiprows=1)
data_A_s_1_50 = np.loadtxt(file_A_s_1_50,skiprows=1)
data_A_s_2_00 = np.loadtxt(file_A_s_2_00,skiprows=1)
data_A_s_2_50 = np.loadtxt(file_A_s_2_50,skiprows=1)
data_A_s_3_00 = np.loadtxt(file_A_s_3_00,skiprows=1)
data_A_s_3_50 = np.loadtxt(file_A_s_3_50,skiprows=1)

data_omega_lambda_0_50 = np.loadtxt(file_omega_lambda_0_50,skiprows=1)
data_omega_lambda_0_60 = np.loadtxt(file_omega_lambda_0_60,skiprows=1)
data_omega_lambda_0_80 = np.loadtxt(file_omega_lambda_0_80,skiprows=1)
data_omega_lambda_0_90 = np.loadtxt(file_omega_lambda_0_90,skiprows=1)

data_omega_b_0_005 = np.loadtxt(file_omega_b_0_005,skiprows=1)
data_omega_b_0_010 = np.loadtxt(file_omega_b_0_010,skiprows=1)
data_omega_b_0_100 = np.loadtxt(file_omega_b_0_100,skiprows=1)
data_omega_b_0_313 = np.loadtxt(file_omega_b_0_313,skiprows=1)

# %%
# Trimming down the data to max of L = 2508, to be consistent with Planck observational power spectra.
# As a side note, there's a weird kink at L ~ 2500 that I can't explain. Perhaps a rounding error?
#plt.plot(axis,data_nominal)   #uncomment me to see the kink at L=2500

data_nominal = data_nominal[0:2507]
axis = axis[0:2507]
print("Data ranges from L = "+str(axis[0])+" to L = "+str(axis[-1]))


data_h0_0_20 = data_h0_0_20[0:2507]
data_h0_0_30 = data_h0_0_30[0:2507]
data_h0_0_40 = data_h0_0_40[0:2507]
data_h0_0_50 = data_h0_0_50[0:2507]
data_h0_0_60 = data_h0_0_60[0:2507]
data_h0_0_65 = data_h0_0_65[0:2507]
data_h0_0_66 = data_h0_0_66[0:2507]
data_h0_0_68 = data_h0_0_68[0:2507]
data_h0_0_69 = data_h0_0_69[0:2507]
data_h0_0_70 = data_h0_0_70[0:2507]
data_h0_0_80 = data_h0_0_80[0:2507]
data_h0_0_90 = data_h0_0_90[0:2507]
data_h0_0_100 = data_h0_0_100[0:2507]

data_tau_0_01 = data_tau_0_01[0:2507]
data_tau_0_02 = data_tau_0_02[0:2507]
data_tau_0_03 = data_tau_0_03[0:2507]
data_tau_0_04 = data_tau_0_04[0:2507]
data_tau_0_05 = data_tau_0_05[0:2507]
data_tau_0_06 = data_tau_0_06[0:2507]
data_tau_0_07 = data_tau_0_07[0:2507]
data_tau_0_09 = data_tau_0_09[0:2507]
data_tau_0_10 = data_tau_0_10[0:2507]
data_tau_0_11 = data_tau_0_11[0:2507]
data_tau_0_50 = data_tau_0_50[0:2507]

data_ns_0_20 = data_ns_0_20[0:2507]
data_ns_0_50 = data_ns_0_50[0:2507]
data_ns_0_70 = data_ns_0_70[0:2507]
data_ns_0_80 = data_ns_0_80[0:2507]
data_ns_0_90 = data_ns_0_90[0:2507]
data_ns_1_00 = data_ns_1_00[0:2507]
data_ns_1_10 = data_ns_1_10[0:2507]
data_ns_1_20 = data_ns_1_20[0:2507]

data_A_s_0_50 = data_A_s_0_50[0:2507]
data_A_s_1_00 = data_A_s_1_00[0:2507]
data_A_s_1_50 = data_A_s_1_50[0:2507]
data_A_s_2_00 = data_A_s_2_00[0:2507]
data_A_s_2_50 = data_A_s_2_50[0:2507]
data_A_s_3_00 = data_A_s_3_00[0:2507]
data_A_s_3_50 = data_A_s_3_50[0:2507]

data_omega_lambda_0_50 = data_omega_lambda_0_50[0:2507]
data_omega_lambda_0_60 = data_omega_lambda_0_60[0:2507]
data_omega_lambda_0_80 = data_omega_lambda_0_80[0:2507]
data_omega_lambda_0_90 = data_omega_lambda_0_90[0:2507]

data_omega_b_0_005 = data_omega_b_0_005[0:2507]
data_omega_b_0_010 = data_omega_b_0_010[0:2507]
data_omega_b_0_100 = data_omega_b_0_100[0:2507]
data_omega_b_0_313 = data_omega_b_0_313[0:2507]
# Out:
# Data ranges from L = 2.0 to L = 2508.0

# %% [markdown]
# Now we start plotting! I've included a star(*) next to the label for each nominal value.

# %%
# Start by plotting the 'close' H_0 values to see a subtle variation.
#plt.style.use("fivethirtyeight")
# http://www.perbang.dk/rgbgradient/       use this for colors

plt.plot(axis, data_h0_0_65, label='$H_0$ = 65.0', color='#E56100')
plt.plot(axis, data_h0_0_66, label='$H_0$ = 66.0', color='#AB642F')
plt.plot(axis, data_nominal, label='$H_0$ = 67.3 *', color='#72675F')
plt.plot(axis, data_h0_0_68, label='$H_0$ = 68.0', color='#396A8F')
plt.plot(axis, data_h0_0_69, label='$H_0$ = 69.0', color='#006EBF')


plt.legend(loc='upper right')
plt.xlabel('$\ell$')
plt.ylabel(r'$\frac {\ell (\ell+1)} {2 \pi}$ $C_\ell$  [$\mu$K$^2$]')
plt.title('Simulated Power Spectra at Various $H_0$ Values')

plt.savefig('./Varied-h_0-TT.pdf', bbox_inches='tight')
plt.savefig('./Varied-h_0-TT.png', bbox_inches='tight', dpi=300)

# %%
# ...So you can play around with various styles...
print(plt.style.available)

# ...So you can reset it when you realize all the other styles are actually super ugly...
import matplotlib.pyplot as plt
# Out:
# [u'seaborn-darkgrid', u'seaborn-notebook', u'classic', u'seaborn-ticks', u'grayscale', u'bmh', u'seaborn-talk', u'dark_background', u'ggplot', u'fivethirtyeight', u'_classic_test', u'seaborn-colorblind', u'seaborn-deep', u'seaborn-whitegrid', u'seaborn-bright', u'seaborn-poster', u'seaborn-muted', u'seaborn-paper', u'seaborn-white', u'seaborn-pastel', u'seaborn-dark', u'seaborn', u'seaborn-dark-palette']

# %%
plt.plot(axis, data_h0_0_40, label='$H_0$ = 45.0', color='#E56100', linestyle='dashdot')
plt.plot(axis, data_h0_0_50, label='$H_0$ = 50.0', color='#AB642F', linestyle='dashed')
plt.plot(axis, data_nominal, label='$H_0$ = 67.3 *', color='#72675F')
plt.plot(axis, data_h0_0_80, label='$H_0$ = 80.0', color='#396A8F', linestyle='dashed')
plt.plot(axis, data_h0_0_90, label='$H_0$ = 90.0', color='#006EBF', linestyle='dashdot')


plt.legend(loc='upper right')
plt.xlabel('$\ell$')
plt.ylabel(r'$\frac {\ell (\ell+1)} {2 \pi}$ $C_\ell$  [$\mu$K$^2$]')
plt.title('Simulated Power Spectra at Various $H_0$ Values')

#plt.savefig('./Wide-Varied-h_0-TT_dash.pdf', bbox_inches='tight')
#plt.savefig('./Wide-Varied-h_0-TT_dash.png', bbox_inches='tight', dpi=300)

# %%
# Now some plots for tau...

plt.plot(axis, data_tau_0_06, label=r'$\tau$ = 0.060', color='#E56100')
plt.plot(axis, data_tau_0_07, label=r'$\tau$ = 0.070', color='#AB642F')
plt.plot(axis, data_nominal, label=r'$\tau$ = 0.078 *', color='#72675F')
plt.plot(axis, data_tau_0_09, label=r'$\tau$ = 0.090', color='#396A8F')
plt.plot(axis, data_tau_0_10, label=r'$\tau$ = 0.100', color='#006EBF')


plt.legend(loc='upper right')
plt.xlabel('$\ell$')
plt.ylabel(r'$\frac {\ell (\ell+1)} {2 \pi}$ $C_\ell$  [$\mu$K$^2$]')
plt.title(r'Simulated Power Spectra at Various $\tau$ Values')

plt.savefig('./Varied-tau-TT.pdf', bbox_inches='tight')
plt.savefig('./Varied-tau-TT.png', bbox_inches='tight', dpi=300)

# %%
## Now some plots for tau...

plt.plot(axis, data_tau_0_01, label=r'$\tau$ = 0.010', color='#AB642F')
#plt.plot(axis, data_tau_0_02, label=r'$\tau$ = 0.020', color='#72675F')
#plt.plot(axis, data_tau_0_03, label=r'$\tau$ = 0.030', color='#72675F')
#plt.plot(axis, data_tau_0_04, label=r'$\tau$ = 0.040', color='#72675F')
#plt.plot(axis, data_tau_0_05, label=r'$\tau$ = 0.050', color='#72675F')
#plt.plot(axis, data_tau_0_06, label=r'$\tau$ = 0.060', color='#72675F')
#plt.plot(axis, data_tau_0_07, label=r'$\tau$ = 0.070', color='#72675F')
plt.plot(axis, data_nominal, label=r'$\tau$ = 0.078 *', color='#FF0000')
#plt.plot(axis, data_tau_0_09, label=r'$\tau$ = 0.080', color='#72675F')
#plt.plot(axis, data_tau_0_10, label=r'$\tau$ = 0.090', color='#72675F')
#plt.plot(axis, data_tau_0_11, label=r'$\tau$ = 0.100', color='#72675F')
plt.plot(axis, data_tau_0_50, label=r'$\tau$ = 0.500', color='#396A8F')


plt.legend(loc='upper right')
plt.xlabel('$\ell$')
plt.ylabel(r'$\frac {\ell (\ell+1)} {2 \pi}$ $C_\ell$  [$\mu$K$^2$]')
plt.title(r'Simulated Power Spectra at Various $\tau$ Values')

plt.savefig('./Wide-Varied-tau-TT.pdf', bbox_inches='tight')
plt.savefig('./Wide-Varied-tau-TT.png', bbox_inches='tight', dpi=300)

# %%
# n_s plots

plt.plot(axis, data_ns_0_80, label=r'$n_s$ = 0.80', color='#E56100')
plt.plot(axis, data_ns_0_90, label=r'$n_s$ = 0.90', color='#AB642F')
plt.plot(axis, data_nominal, label=r'$n_s$ = 0.9658 *', color='#72675F')
plt.plot(axis, data_ns_1_00, label=r'$n_s$ = 1.00', color='#396A8F')
plt.plot(axis, data_ns_1_10, label=r'$n_s$ = 1.10', color='#006EBF')


plt.legend(loc='upper right')
plt.xlabel('$\ell$')
plt.ylabel(r'$\frac {\ell (\ell+1)} {2 \pi}$ $C_\ell$  [$\mu$K$^2$]')
plt.title(r'Simulated Power Spectra at Various $n_s$ Values')

plt.savefig('./Varied-n_s-TT.pdf', bbox_inches='tight')
plt.savefig('./Varied-n_s-TT.png', bbox_inches='tight', dpi=300)

# %%
# linear n_s plots, clipped the high L to avoid divide by zero issues

plt.loglog(axis[0:2000], data_ns_0_80[0:2000]/data_nominal[0:2000], label=r'$n_s$ = 0.80', color='#E56100')
plt.loglog(axis[0:2000], data_ns_0_90[0:2000]/data_nominal[0:2000], label=r'$n_s$ = 0.90', color='#AB642F')
plt.loglog(axis[0:2000], data_nominal[0:2000]/data_nominal[0:2000], label=r'$n_s$ = 0.9658 *', color='#72675F')
plt.loglog(axis[0:2000], data_ns_1_00[0:2000]/data_nominal[0:2000], label=r'$n_s$ = 1.00', color='#396A8F')
plt.loglog(axis[0:2000], data_ns_1_10[0:2000]/data_nominal[0:2000], label=r'$n_s$ = 1.10', color='#006EBF')

plt.legend(loc='upper right')
plt.xlabel('$\ell$')
plt.title(r'Flattened $n_s$ Spectral Index [Log]')

plt.savefig('./Varied-n_s-flattened-TT.pdf', bbox_inches='tight')
plt.savefig('./Varied-n_s-flattened-TT.png', bbox_inches='tight', dpi=300)

# %%
# A_s plots

plt.plot(axis, data_A_s_1_50, label=r'$A_s$ = 1.50 $x10^{-9}$', color='#E56100')
plt.plot(axis, data_A_s_2_00, label=r'$A_s$ = 2.00 $x10^{-9}$', color='#AB642F')
plt.plot(axis, data_nominal, label=r'$A_s$ = 2.20 $x10^{-9}$ *', color='#72675F')
plt.plot(axis, data_A_s_2_50, label=r'$A_s$ = 2.50 $x10^{-9}$', color='#396A8F')
plt.plot(axis, data_A_s_3_00, label=r'$A_s$ = 3.00 $x10^{-9}$', color='#006EBF')


plt.legend(loc='upper right')
plt.xlabel('$\ell$')
plt.ylabel(r'$\frac {\ell (\ell+1)} {2 \pi}$ $C_\ell$  [$\mu$K$^2$]')
plt.title(r'Simulated Power Spectra at Various $A_s$ Values')

plt.savefig('./Varied-A_s-TT.pdf', bbox_inches='tight')
plt.savefig('./Varied-A_s-TT.png', bbox_inches='tight', dpi=300)

# %%
# Omega_lambda plots

plt.plot(axis, data_omega_lambda_0_50, label=r'$\Omega_{\Lambda}$ = 0.50', color='#E56100')
plt.plot(axis, data_omega_lambda_0_60, label=r'$\Omega_{\Lambda}$ = 0.60', color='#AB642F')
plt.plot(axis, data_nominal, label=r'$\Omega_{\Lambda}$ = 0.69 *', color='#72675F')
plt.plot(axis, data_omega_lambda_0_80, label=r'$\Omega_{\Lambda}$ = 0.80', color='#396A8F')
plt.plot(axis, data_omega_lambda_0_90, label=r'$\Omega_{\Lambda}$ = 0.90', color='#006EBF')

plt.legend(loc='upper right')
plt.xlabel('$\ell$')
plt.ylabel(r'$\frac {\ell (\ell+1)} {2 \pi}$ $C_\ell$  [$\mu$K$^2$]')
plt.title(r'Simulated Power Spectra at Various $\Omega_{\Lambda}$ Values ($\Omega_b / \Omega_c$ fixed)')

plt.savefig('./Varied-omega_lambda-TT.pdf', bbox_inches='tight')
plt.savefig('./Varied-omega_lambda-TT.png', bbox_inches='tight', dpi=300)

# Inverse degeneracy with H_0!!

# %%
plt.plot(axis, data_omega_b_0_005, label=r'$\Omega_{b}$ = 0.005', color='#E56100')
plt.plot(axis, data_omega_b_0_010, label=r'$\Omega_{b}$ = 0.010', color='#AB642F')
plt.plot(axis, data_nominal, label=r'$\Omega_{b}$ = 0.049 *', color='#72675F')
plt.plot(axis, data_omega_b_0_100, label=r'$\Omega_{b}$ = 0.100', color='#396A8F')
plt.plot(axis, data_omega_b_0_313, label=r'$\Omega_{b}$ = 0.313', color='#006EBF')

plt.legend(loc='upper right')
plt.xlabel('$\ell$')
plt.ylabel(r'$\frac {\ell (\ell+1)} {2 \pi}$ $C_\ell$  [$\mu$K$^2$]')
plt.title(r'Simulated Power Spectra at Various $\Omega_{b}$ Values ($\Omega_{\Lambda}$, $\Omega_{m}$ fixed)')

plt.savefig('./Varied-omega_b-TT.pdf', bbox_inches='tight')
plt.savefig('./Varied-omega_b-TT.png', bbox_inches='tight', dpi=300)
